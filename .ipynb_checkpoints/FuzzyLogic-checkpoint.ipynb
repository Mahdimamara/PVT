# %%
import numpy as np
import skfuzzy
from skfuzzy import control

# %%
#Input Variables
Trad = control.Antecedent(np.arange(0, 169, 0.1), 'Trad')
IF = control.Antecedent(np.arange(-0.2, 0.16, 0.001), 'IF')
DBSCAN = control.Antecedent(np.arange(-1, 0.1, 0.01), 'DBSCAN')
LOF = control.Antecedent(np.arange(-4.5, 0, 0.01), 'LOF')
OCSVM = control.Antecedent(np.arange(1, 13, 0.1), 'OCSVM')
ABOD = control.Antecedent(np.arange(0, 0.05, 0.0001), 'ABOD')
Sample = control.Consequent(np.arange(-50, 50, 0.1), 'Sample')

# %%
#membership functions (trapezoidal)
Trad['In']    = skfuzzy.trapmf(Trad.universe, [0, 0, 9.5, 18])
Trad['Out']   = skfuzzy.trapmf(Trad.universe, [9.5, 18, 169, 169])
IF['Out']     = skfuzzy.trapmf(IF.universe, [-0.2, -0.2, 0.046, 0.1])
IF['In']      = skfuzzy.trapmf(IF.universe, [0.046, 0.1, 0.16, 0.16])
DBSCAN['Out'] = skfuzzy.trapmf(DBSCAN.universe, [-1, -1, -0.6, -0.3])
DBSCAN['In']  = skfuzzy.trapmf(DBSCAN.universe, [-0.6, -0.3, 0.1, 0.1])
LOF['Out']    = skfuzzy.trapmf(LOF.universe, [-4.5, -4.5, -1.15, -0.99])
LOF['In']     = skfuzzy.trapmf(LOF.universe, [-1.15, -0.99, 0, 0])
OCSVM['Out']  = skfuzzy.trapmf(OCSVM.universe, [1, 1, 10, 11.8])
OCSVM['In']   = skfuzzy.trapmf(OCSVM.universe, [10, 11.8, 13, 13])
ABOD['Out']   = skfuzzy.trapmf(ABOD.universe, [0, 0, 0.0028, 0.017])
ABOD['In']    = skfuzzy.trapmf(ABOD.universe, [0.0028, 0.017, 0.05, 0.05])

Sample['Best Rep.'] = skfuzzy.trapmf(Sample.universe, [30, 40, 50, 50])
Sample['Good Rep.'] = skfuzzy.trapmf(Sample.universe, [10, 20, 30, 40])
Sample['Moderate']  = skfuzzy.trapmf(Sample.universe, [-20, 0, 10, 20])
Sample['Outlier']   = skfuzzy.trapmf(Sample.universe, [-50, -50, -20, 0])

Trad.view()
IF.view()
DBSCAN.view()
LOF.view()
OCSVM.view()
ABOD.view()
Sample.view()
# Out:
# C:\Users\Mehdi\AppData\Local\Programs\Python\Python310\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Mehdi\AppData\Local\Programs\Python\Python310\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Mehdi\AppData\Local\Programs\Python\Python310\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Mehdi\AppData\Local\Programs\Python\Python310\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Mehdi\AppData\Local\Programs\Python\Python310\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Mehdi\AppData\Local\Programs\Python\Python310\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Mehdi\AppData\Local\Programs\Python\Python310\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Defining Rule
T = [Trad['In'], Trad['Out']]
I = [IF['In'], IF['Out']]
D = [DBSCAN['In'], DBSCAN['Out']]
L = [LOF['In'], LOF['Out']]
O = [OCSVM['In'], OCSVM['Out']]
A = [ABOD['In'], ABOD['Out']]
counter = 0
R = []
for i in T:
    for j in I:
        for k in D:
            for l in L:
                for m in O:
                    for n in A:
                        R.append(i & j & k & l & m & n)
                        print(counter, i & j & k & l & m & n)
                        counter += 1


rule1 = control.Rule(R[0] , Sample['Best Rep.'])
rule2 = control.Rule(R[1]  | R[2] | R[4] | R[8] | R[16] | R[32], Sample['Good Rep.'])
rule3 = control.Rule(R[3] |R[5] |R[6] |R[9] |R[10] |R[12] |R[17] | R[18] | R[20] | R[24] | R[33] | R[34] | R[36] | R[40] | R[48] , Sample['Moderate'])
rule4 = control.Rule(R[11] |R[13] |R[14] |R[19] |R[21] |R[22] |R[41] |R[42] |R[44] |R[7] |R[25] |R[26] |R[28] |R[35] |R[37] |R[38] |R[49] |R[50] |R[52] |R[56] , Sample['Moderate'])
rule5 = control.Rule(R[15] |R[23] |R[27] |R[29] |R[30] |R[39] |R[43] |R[45] |R[46] |R[51] |R[53] |R[54] |R[57] |R[58] |R[60] , Sample['Outlier'])
rule6 = control.Rule(R[62] | R[61] | R[59] | R[55]|R[47]|R[31],Sample['Outlier'])
rule7 = control.Rule(R[63] , Sample['Outlier'])


Rules =control.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7])
Outlier = control.ControlSystemSimulation(Rules)
# Out:
# 0 ((((Trad[In] AND IF[In]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[In]) AND ABOD[In]
# 1 ((((Trad[In] AND IF[In]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[In]) AND ABOD[Out]
# 2 ((((Trad[In] AND IF[In]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[In]
# 3 ((((Trad[In] AND IF[In]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[Out]
# 4 ((((Trad[In] AND IF[In]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[In]
# 5 ((((Trad[In] AND IF[In]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[Out]
# 6 ((((Trad[In] AND IF[In]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[In]
# 7 ((((Trad[In] AND IF[In]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[Out]
# 8 ((((Trad[In] AND IF[In]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[In]) AND ABOD[In]
# 9 ((((Trad[In] AND IF[In]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[In]) AND ABOD[Out]
# 10 ((((Trad[In] AND IF[In]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[In]
# 11 ((((Trad[In] AND IF[In]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[Out]
# 12 ((((Trad[In] AND IF[In]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[In]
# 13 ((((Trad[In] AND IF[In]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[Out]
# 14 ((((Trad[In] AND IF[In]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[In]
# 15 ((((Trad[In] AND IF[In]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[Out]
# 16 ((((Trad[In] AND IF[Out]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[In]) AND ABOD[In]
# 17 ((((Trad[In] AND IF[Out]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[In]) AND ABOD[Out]
# 18 ((((Trad[In] AND IF[Out]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[In]
# 19 ((((Trad[In] AND IF[Out]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[Out]
# 20 ((((Trad[In] AND IF[Out]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[In]
# 21 ((((Trad[In] AND IF[Out]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[Out]
# 22 ((((Trad[In] AND IF[Out]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[In]
# 23 ((((Trad[In] AND IF[Out]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[Out]
# 24 ((((Trad[In] AND IF[Out]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[In]) AND ABOD[In]
# 25 ((((Trad[In] AND IF[Out]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[In]) AND ABOD[Out]
# 26 ((((Trad[In] AND IF[Out]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[In]
# 27 ((((Trad[In] AND IF[Out]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[Out]
# 28 ((((Trad[In] AND IF[Out]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[In]
# 29 ((((Trad[In] AND IF[Out]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[Out]
# 30 ((((Trad[In] AND IF[Out]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[In]
# 31 ((((Trad[In] AND IF[Out]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[Out]
# 32 ((((Trad[Out] AND IF[In]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[In]) AND ABOD[In]
# 33 ((((Trad[Out] AND IF[In]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[In]) AND ABOD[Out]
# 34 ((((Trad[Out] AND IF[In]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[In]
# 35 ((((Trad[Out] AND IF[In]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[Out]
# 36 ((((Trad[Out] AND IF[In]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[In]
# 37 ((((Trad[Out] AND IF[In]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[Out]
# 38 ((((Trad[Out] AND IF[In]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[In]
# 39 ((((Trad[Out] AND IF[In]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[Out]
# 40 ((((Trad[Out] AND IF[In]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[In]) AND ABOD[In]
# 41 ((((Trad[Out] AND IF[In]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[In]) AND ABOD[Out]
# 42 ((((Trad[Out] AND IF[In]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[In]
# 43 ((((Trad[Out] AND IF[In]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[Out]
# 44 ((((Trad[Out] AND IF[In]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[In]
# 45 ((((Trad[Out] AND IF[In]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[Out]
# 46 ((((Trad[Out] AND IF[In]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[In]
# 47 ((((Trad[Out] AND IF[In]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[Out]
# 48 ((((Trad[Out] AND IF[Out]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[In]) AND ABOD[In]
# 49 ((((Trad[Out] AND IF[Out]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[In]) AND ABOD[Out]
# 50 ((((Trad[Out] AND IF[Out]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[In]
# 51 ((((Trad[Out] AND IF[Out]) AND DBSCAN[In]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[Out]
# 52 ((((Trad[Out] AND IF[Out]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[In]
# 53 ((((Trad[Out] AND IF[Out]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[Out]
# 54 ((((Trad[Out] AND IF[Out]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[In]
# 55 ((((Trad[Out] AND IF[Out]) AND DBSCAN[In]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[Out]
# 56 ((((Trad[Out] AND IF[Out]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[In]) AND ABOD[In]
# 57 ((((Trad[Out] AND IF[Out]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[In]) AND ABOD[Out]
# 58 ((((Trad[Out] AND IF[Out]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[In]
# 59 ((((Trad[Out] AND IF[Out]) AND DBSCAN[Out]) AND LOF[In]) AND OCSVM[Out]) AND ABOD[Out]
# 60 ((((Trad[Out] AND IF[Out]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[In]
# 61 ((((Trad[Out] AND IF[Out]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[In]) AND ABOD[Out]
# 62 ((((Trad[Out] AND IF[Out]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[In]
# 63 ((((Trad[Out] AND IF[Out]) AND DBSCAN[Out]) AND LOF[Out]) AND OCSVM[Out]) AND ABOD[Out]

# %%
#Inputs
def TakingValues(a, b, c, d, e, f):
    Outlier.input['Trad']   = a
    Outlier.input['IF']     = b
    Outlier.input['DBSCAN'] = c
    Outlier.input['LOF']    = d
    Outlier.input['OCSVM']  = e
    Outlier.input['ABOD']   = f
    
Outlier.input['Trad']   = 17.7
Outlier.input['IF']     = -0.07
Outlier.input['DBSCAN'] = 0
Outlier.input['LOF']    = -1.05
Outlier.input['OCSVM']  = 10.16
Outlier.input['ABOD']   = 0.018

Outlier.compute()
print(Outlier.output['Sample'])
Sample.view(sim=Outlier)
# Out:
# -11.397437200004026
# C:\Users\Mehdi\AppData\Local\Programs\Python\Python310\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
